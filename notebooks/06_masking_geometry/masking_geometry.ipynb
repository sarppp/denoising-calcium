# %% [markdown]
# # 06 — Masking geometry for N2V training
#
# **Purpose:** optimize 3D patch size and masking strategy for N2V3D training.

# %%
from load_data import load_validation_stacks
stacks = load_validation_stacks()

# %%
from metrics import compute_masked_statistics
masking_results = compute_masked_statistics(stacks['F0'], mask_size=1)

# %%
from analysis import print_masking_summary
from plots import plot_patch_visualization
print_masking_summary(masking_results)
plot_patch_visualization(stacks['F0'], patch_size=64)
# Out:
# ...
# MASKING GEOMETRY ANALYSIS
# ...
#
# Mask size: 1
# Center patch mean intensity: 84.0
# Center patch variance: 478.1
